# %%
from project_utils import load_data
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)

# %%
train_set, valid_set, test_set = load_data()

# %%
train_set_x, train_set_y = train_set
print(train_set_x.shape)

# %%
from test_layer import test_network


#test_network(n_layers, activation=T.Tanh, learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
#            batch_size=20, n_hidden=500, verbose=False)

val_matrix, test_matrix = test_network(n_layers = 10, n_epochs = 150, n_hidden=71, verbose=True)
# Out:
# ... building the model
# ... training
# epoch 1, minibatch 2500/2500, validation error 10.740000 %
#      epoch 1, minibatch 2500/2500, test error of best model 11.470000 %
# epoch 2, minibatch 2500/2500, validation error 7.590000 %
#      epoch 2, minibatch 2500/2500, test error of best model 8.120000 %
# epoch 3, minibatch 2500/2500, validation error 6.570000 %
#      epoch 3, minibatch 2500/2500, test error of best model 7.350000 %
# epoch 4, minibatch 2500/2500, validation error 5.710000 %
#      epoch 4, minibatch 2500/2500, test error of best model 6.610000 %
# epoch 5, minibatch 2500/2500, validation error 4.970000 %
#      epoch 5, minibatch 2500/2500, test error of best model 5.670000 %
# epoch 6, minibatch 2500/2500, validation error 4.540000 %
#      epoch 6, minibatch 2500/2500, test error of best model 5.080000 %
# epoch 7, minibatch 2500/2500, validation error 4.430000 %
#      epoch 7, minibatch 2500/2500, test error of best model 4.830000 %
# epoch 8, minibatch 2500/2500, validation error 4.210000 %
#      epoch 8, minibatch 2500/2500, test error of best model 4.940000 %
# epoch 9, minibatch 2500/2500, validation error 4.030000 %
#      epoch 9, minibatch 2500/2500, test error of best model 4.660000 %
# epoch 10, minibatch 2500/2500, validation error 3.900000 %
#      epoch 10, minibatch 2500/2500, test error of best model 4.380000 %
# epoch 11, minibatch 2500/2500, validation error 3.640000 %
#      epoch 11, minibatch 2500/2500, test error of best model 4.190000 %
# epoch 12, minibatch 2500/2500, validation error 3.770000 %
# epoch 13, minibatch 2500/2500, validation error 3.850000 %
# epoch 14, minibatch 2500/2500, validation error 3.630000 %
#      epoch 14, minibatch 2500/2500, test error of best model 4.110000 %
# epoch 15, minibatch 2500/2500, validation error 4.040000 %
# epoch 16, minibatch 2500/2500, validation error 3.290000 %
#      epoch 16, minibatch 2500/2500, test error of best model 3.720000 %
# epoch 17, minibatch 2500/2500, validation error 3.350000 %
# epoch 18, minibatch 2500/2500, validation error 3.180000 %
#      epoch 18, minibatch 2500/2500, test error of best model 3.650000 %
# epoch 19, minibatch 2500/2500, validation error 3.410000 %
# epoch 20, minibatch 2500/2500, validation error 2.920000 %
#      epoch 20, minibatch 2500/2500, test error of best model 3.490000 %
# epoch 21, minibatch 2500/2500, validation error 2.850000 %
#      epoch 21, minibatch 2500/2500, test error of best model 3.250000 %
# epoch 22, minibatch 2500/2500, validation error 3.350000 %
# epoch 23, minibatch 2500/2500, validation error 2.690000 %
#      epoch 23, minibatch 2500/2500, test error of best model 3.220000 %
# epoch 24, minibatch 2500/2500, validation error 2.940000 %
# epoch 25, minibatch 2500/2500, validation error 3.050000 %
# epoch 26, minibatch 2500/2500, validation error 2.830000 %
# epoch 27, minibatch 2500/2500, validation error 2.550000 %
#      epoch 27, minibatch 2500/2500, test error of best model 2.980000 %
# epoch 28, minibatch 2500/2500, validation error 3.000000 %
# epoch 29, minibatch 2500/2500, validation error 2.640000 %
# epoch 30, minibatch 2500/2500, validation error 2.550000 %
# epoch 31, minibatch 2500/2500, validation error 2.810000 %
# epoch 32, minibatch 2500/2500, validation error 2.720000 %
# epoch 33, minibatch 2500/2500, validation error 2.510000 %
#      epoch 33, minibatch 2500/2500, test error of best model 2.890000 %
# epoch 34, minibatch 2500/2500, validation error 2.830000 %
# epoch 35, minibatch 2500/2500, validation error 2.570000 %
# epoch 36, minibatch 2500/2500, validation error 2.480000 %
#      epoch 36, minibatch 2500/2500, test error of best model 3.020000 %
# epoch 37, minibatch 2500/2500, validation error 2.560000 %
# epoch 38, minibatch 2500/2500, validation error 2.480000 %
# epoch 39, minibatch 2500/2500, validation error 3.060000 %
# epoch 40, minibatch 2500/2500, validation error 2.610000 %
# epoch 41, minibatch 2500/2500, validation error 2.540000 %
# epoch 42, minibatch 2500/2500, validation error 2.570000 %
# epoch 43, minibatch 2500/2500, validation error 2.420000 %
#      epoch 43, minibatch 2500/2500, test error of best model 2.730000 %
# epoch 44, minibatch 2500/2500, validation error 2.530000 %
# epoch 45, minibatch 2500/2500, validation error 2.380000 %
#      epoch 45, minibatch 2500/2500, test error of best model 2.550000 %
# epoch 46, minibatch 2500/2500, validation error 2.370000 %
#      epoch 46, minibatch 2500/2500, test error of best model 2.610000 %
# epoch 47, minibatch 2500/2500, validation error 2.280000 %
#      epoch 47, minibatch 2500/2500, test error of best model 2.550000 %
# epoch 48, minibatch 2500/2500, validation error 2.220000 %
#      epoch 48, minibatch 2500/2500, test error of best model 2.590000 %
# epoch 49, minibatch 2500/2500, validation error 2.200000 %
#      epoch 49, minibatch 2500/2500, test error of best model 2.620000 %
# epoch 50, minibatch 2500/2500, validation error 2.220000 %
# epoch 51, minibatch 2500/2500, validation error 2.210000 %
# epoch 52, minibatch 2500/2500, validation error 2.210000 %
# epoch 53, minibatch 2500/2500, validation error 2.140000 %
#      epoch 53, minibatch 2500/2500, test error of best model 2.560000 %
# epoch 54, minibatch 2500/2500, validation error 2.140000 %
#      epoch 54, minibatch 2500/2500, test error of best model 2.560000 %
# epoch 55, minibatch 2500/2500, validation error 2.150000 %
# epoch 56, minibatch 2500/2500, validation error 2.150000 %
# epoch 57, minibatch 2500/2500, validation error 2.170000 %
# epoch 58, minibatch 2500/2500, validation error 2.170000 %
# epoch 59, minibatch 2500/2500, validation error 2.200000 %
# epoch 60, minibatch 2500/2500, validation error 2.190000 %
# epoch 61, minibatch 2500/2500, validation error 2.210000 %
# epoch 62, minibatch 2500/2500, validation error 2.210000 %
# epoch 63, minibatch 2500/2500, validation error 2.220000 %
# epoch 64, minibatch 2500/2500, validation error 2.220000 %
# epoch 65, minibatch 2500/2500, validation error 2.240000 %
# epoch 66, minibatch 2500/2500, validation error 2.250000 %
# epoch 67, minibatch 2500/2500, validation error 2.280000 %
# epoch 68, minibatch 2500/2500, validation error 2.290000 %
# epoch 69, minibatch 2500/2500, validation error 2.300000 %
# epoch 70, minibatch 2500/2500, validation error 2.310000 %
# epoch 71, minibatch 2500/2500, validation error 2.300000 %
# epoch 72, minibatch 2500/2500, validation error 2.300000 %
# epoch 73, minibatch 2500/2500, validation error 2.300000 %
# epoch 74, minibatch 2500/2500, validation error 2.290000 %
# epoch 75, minibatch 2500/2500, validation error 2.290000 %
# epoch 76, minibatch 2500/2500, validation error 2.280000 %
# epoch 77, minibatch 2500/2500, validation error 2.280000 %
# epoch 78, minibatch 2500/2500, validation error 2.270000 %
# epoch 79, minibatch 2500/2500, validation error 2.250000 %
# epoch 80, minibatch 2500/2500, validation error 2.280000 %
# epoch 81, minibatch 2500/2500, validation error 2.290000 %
# epoch 82, minibatch 2500/2500, validation error 2.290000 %
# epoch 83, minibatch 2500/2500, validation error 2.290000 %
# epoch 84, minibatch 2500/2500, validation error 2.290000 %
# epoch 85, minibatch 2500/2500, validation error 2.290000 %
# epoch 86, minibatch 2500/2500, validation error 2.310000 %
# epoch 87, minibatch 2500/2500, validation error 2.310000 %
# epoch 88, minibatch 2500/2500, validation error 2.310000 %
# epoch 89, minibatch 2500/2500, validation error 2.310000 %
# epoch 90, minibatch 2500/2500, validation error 2.310000 %
# epoch 91, minibatch 2500/2500, validation error 2.310000 %
# epoch 92, minibatch 2500/2500, validation error 2.290000 %
# epoch 93, minibatch 2500/2500, validation error 2.290000 %
# epoch 94, minibatch 2500/2500, validation error 2.300000 %
# epoch 95, minibatch 2500/2500, validation error 2.300000 %
# epoch 96, minibatch 2500/2500, validation error 2.310000 %
# epoch 97, minibatch 2500/2500, validation error 2.320000 %
# epoch 98, minibatch 2500/2500, validation error 2.330000 %
# epoch 99, minibatch 2500/2500, validation error 2.330000 %
# epoch 100, minibatch 2500/2500, validation error 2.340000 %
# epoch 101, minibatch 2500/2500, validation error 2.330000 %
# epoch 102, minibatch 2500/2500, validation error 2.340000 %
# epoch 103, minibatch 2500/2500, validation error 2.340000 %
# epoch 104, minibatch 2500/2500, validation error 2.350000 %
# epoch 105, minibatch 2500/2500, validation error 2.360000 %
# epoch 106, minibatch 2500/2500, validation error 2.360000 %
# epoch 107, minibatch 2500/2500, validation error 2.360000 %
# epoch 108, minibatch 2500/2500, validation error 2.370000 %
# epoch 109, minibatch 2500/2500, validation error 2.380000 %
# epoch 110, minibatch 2500/2500, validation error 2.380000 %
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-abdabcb87937> in <module>()
#       5 #            batch_size=20, n_hidden=500, verbose=False)
#       6
# ----> 7 val_matrix, test_matrix = test_network(n_layers = 10, n_epochs = 150, n_hidden=71, verbose=True)
#
# /home/ubuntu/project/e4040_project_abcd/src/test_layer.pyc in test_network(n_layers, activation, learning_rate, L1_reg, L2_reg, n_epochs, batch_size, n_hidden, verbose)
#     298         for minibatch_index in range(n_train_batches):
#     299
# --> 300             minibatch_avg_cost = train_model(minibatch_index)
#     301             # iteration number
#     302             iter = (epoch - 1) * n_train_batches + minibatch_index
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     864         try:
#     865             outputs =\
# --> 866                 self.fn() if output_subset is None else\
#     867                 self.fn(output_subset=output_subset)
#     868         except Exception:
#
# KeyboardInterrupt:

# %%
import theano.tensor as T
from test_layer import test_network


#test_network(n_layers, activation=T.Tanh, learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
#            batch_size=20, n_hidden=500, verbose=False, Highway=False)

val_matrix, test_matrix = test_network(n_layers = 10, activation = T.nnet.relu, n_epochs = 150, n_hidden=71, verbose=True)
# Out:
# ... building the model
# ... training
# epoch 1, minibatch 2500/2500, validation error 89.360000 %
#      epoch 1, minibatch 2500/2500, test error of best model 88.650000 %
# epoch 2, minibatch 2500/2500, validation error 66.520000 %
#      epoch 2, minibatch 2500/2500, test error of best model 66.540000 %
# epoch 3, minibatch 2500/2500, validation error 10.170000 %
#      epoch 3, minibatch 2500/2500, test error of best model 10.910000 %
# epoch 4, minibatch 2500/2500, validation error 7.590000 %
#      epoch 4, minibatch 2500/2500, test error of best model 8.410000 %
# epoch 5, minibatch 2500/2500, validation error 6.440000 %
#      epoch 5, minibatch 2500/2500, test error of best model 7.010000 %
# epoch 6, minibatch 2500/2500, validation error 5.040000 %
#      epoch 6, minibatch 2500/2500, test error of best model 5.810000 %
# epoch 7, minibatch 2500/2500, validation error 4.740000 %
#      epoch 7, minibatch 2500/2500, test error of best model 5.430000 %
# epoch 8, minibatch 2500/2500, validation error 4.740000 %
# epoch 9, minibatch 2500/2500, validation error 4.800000 %
# epoch 10, minibatch 2500/2500, validation error 4.250000 %
#      epoch 10, minibatch 2500/2500, test error of best model 4.740000 %
# epoch 11, minibatch 2500/2500, validation error 3.730000 %
#      epoch 11, minibatch 2500/2500, test error of best model 4.370000 %
# epoch 12, minibatch 2500/2500, validation error 4.640000 %
# epoch 13, minibatch 2500/2500, validation error 4.070000 %
# epoch 14, minibatch 2500/2500, validation error 4.050000 %
# epoch 15, minibatch 2500/2500, validation error 4.050000 %
# epoch 16, minibatch 2500/2500, validation error 3.360000 %
#      epoch 16, minibatch 2500/2500, test error of best model 3.680000 %
# epoch 17, minibatch 2500/2500, validation error 3.680000 %
# epoch 18, minibatch 2500/2500, validation error 3.120000 %
#      epoch 18, minibatch 2500/2500, test error of best model 3.370000 %
# epoch 19, minibatch 2500/2500, validation error 3.370000 %
# epoch 20, minibatch 2500/2500, validation error 5.040000 %
# epoch 21, minibatch 2500/2500, validation error 2.990000 %
#      epoch 21, minibatch 2500/2500, test error of best model 3.370000 %
# epoch 22, minibatch 2500/2500, validation error 4.240000 %
# epoch 23, minibatch 2500/2500, validation error 4.070000 %
# epoch 24, minibatch 2500/2500, validation error 3.320000 %
# epoch 25, minibatch 2500/2500, validation error 2.910000 %
#      epoch 25, minibatch 2500/2500, test error of best model 3.170000 %
# epoch 26, minibatch 2500/2500, validation error 3.180000 %
# epoch 27, minibatch 2500/2500, validation error 3.010000 %
# epoch 28, minibatch 2500/2500, validation error 2.850000 %
#      epoch 28, minibatch 2500/2500, test error of best model 3.020000 %
# epoch 29, minibatch 2500/2500, validation error 2.910000 %
# epoch 30, minibatch 2500/2500, validation error 2.830000 %
#      epoch 30, minibatch 2500/2500, test error of best model 2.840000 %
# epoch 31, minibatch 2500/2500, validation error 2.880000 %
# epoch 32, minibatch 2500/2500, validation error 2.700000 %
#      epoch 32, minibatch 2500/2500, test error of best model 3.130000 %
# epoch 33, minibatch 2500/2500, validation error 2.760000 %
# epoch 34, minibatch 2500/2500, validation error 2.780000 %
# epoch 35, minibatch 2500/2500, validation error 2.950000 %
# epoch 36, minibatch 2500/2500, validation error 3.160000 %
# epoch 37, minibatch 2500/2500, validation error 2.930000 %
# epoch 38, minibatch 2500/2500, validation error 3.080000 %
# epoch 39, minibatch 2500/2500, validation error 2.730000 %
# epoch 40, minibatch 2500/2500, validation error 2.900000 %
# epoch 41, minibatch 2500/2500, validation error 2.820000 %
# epoch 42, minibatch 2500/2500, validation error 2.760000 %
# epoch 43, minibatch 2500/2500, validation error 2.840000 %
# epoch 44, minibatch 2500/2500, validation error 2.820000 %
# epoch 45, minibatch 2500/2500, validation error 2.820000 %
# epoch 46, minibatch 2500/2500, validation error 2.690000 %
#      epoch 46, minibatch 2500/2500, test error of best model 2.850000 %
# epoch 47, minibatch 2500/2500, validation error 2.800000 %
# epoch 48, minibatch 2500/2500, validation error 2.930000 %
# epoch 49, minibatch 2500/2500, validation error 2.820000 %
# epoch 50, minibatch 2500/2500, validation error 2.700000 %
# epoch 51, minibatch 2500/2500, validation error 2.660000 %
#      epoch 51, minibatch 2500/2500, test error of best model 2.840000 %
# epoch 52, minibatch 2500/2500, validation error 2.880000 %
# epoch 53, minibatch 2500/2500, validation error 2.830000 %
# epoch 54, minibatch 2500/2500, validation error 2.560000 %
#      epoch 54, minibatch 2500/2500, test error of best model 2.620000 %
# epoch 55, minibatch 2500/2500, validation error 2.650000 %
# epoch 56, minibatch 2500/2500, validation error 2.580000 %
# epoch 57, minibatch 2500/2500, validation error 2.600000 %
# epoch 58, minibatch 2500/2500, validation error 2.570000 %
# epoch 59, minibatch 2500/2500, validation error 2.640000 %
# epoch 60, minibatch 2500/2500, validation error 2.570000 %
# epoch 61, minibatch 2500/2500, validation error 2.510000 %
#      epoch 61, minibatch 2500/2500, test error of best model 2.600000 %
# epoch 62, minibatch 2500/2500, validation error 2.650000 %
# epoch 63, minibatch 2500/2500, validation error 2.590000 %
# epoch 64, minibatch 2500/2500, validation error 2.600000 %
# epoch 65, minibatch 2500/2500, validation error 2.520000 %
# epoch 66, minibatch 2500/2500, validation error 2.560000 %
# epoch 67, minibatch 2500/2500, validation error 2.580000 %
# epoch 68, minibatch 2500/2500, validation error 2.560000 %
# epoch 69, minibatch 2500/2500, validation error 2.610000 %
# epoch 70, minibatch 2500/2500, validation error 2.610000 %
# epoch 71, minibatch 2500/2500, validation error 2.590000 %
# epoch 72, minibatch 2500/2500, validation error 2.590000 %
# epoch 73, minibatch 2500/2500, validation error 2.620000 %
# epoch 74, minibatch 2500/2500, validation error 2.640000 %
# epoch 75, minibatch 2500/2500, validation error 2.630000 %
# epoch 76, minibatch 2500/2500, validation error 2.610000 %
# epoch 77, minibatch 2500/2500, validation error 2.620000 %
# epoch 78, minibatch 2500/2500, validation error 2.610000 %
# epoch 79, minibatch 2500/2500, validation error 2.630000 %
# epoch 80, minibatch 2500/2500, validation error 2.630000 %
# epoch 81, minibatch 2500/2500, validation error 2.640000 %
# epoch 82, minibatch 2500/2500, validation error 2.650000 %
# epoch 83, minibatch 2500/2500, validation error 2.640000 %
# epoch 84, minibatch 2500/2500, validation error 2.650000 %
# epoch 85, minibatch 2500/2500, validation error 2.650000 %
# epoch 86, minibatch 2500/2500, validation error 2.650000 %
# epoch 87, minibatch 2500/2500, validation error 2.650000 %
# epoch 88, minibatch 2500/2500, validation error 2.650000 %
# epoch 89, minibatch 2500/2500, validation error 2.640000 %
# epoch 90, minibatch 2500/2500, validation error 2.650000 %
# epoch 91, minibatch 2500/2500, validation error 2.630000 %
# epoch 92, minibatch 2500/2500, validation error 2.650000 %
# epoch 93, minibatch 2500/2500, validation error 2.650000 %
# epoch 94, minibatch 2500/2500, validation error 2.640000 %
# epoch 95, minibatch 2500/2500, validation error 2.640000 %
# epoch 96, minibatch 2500/2500, validation error 2.640000 %
# epoch 97, minibatch 2500/2500, validation error 2.650000 %
# epoch 98, minibatch 2500/2500, validation error 2.650000 %
# epoch 99, minibatch 2500/2500, validation error 2.640000 %
# epoch 100, minibatch 2500/2500, validation error 2.640000 %
# epoch 101, minibatch 2500/2500, validation error 2.650000 %
# epoch 102, minibatch 2500/2500, validation error 2.660000 %
# epoch 103, minibatch 2500/2500, validation error 2.670000 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c2cb5352592f> in <module>()
#       6 #            batch_size=20, n_hidden=500, verbose=False)
#       7
# ----> 8 val_matrix, test_matrix = test_network(n_layers = 10, activation = T.nnet.relu, n_epochs = 150, n_hidden=71, verbose=True)
#       9
#
# /home/ubuntu/project/e4040_project_abcd/src/test_layer.pyc in test_network(n_layers, activation, learning_rate, L1_reg, L2_reg, n_epochs, batch_size, n_hidden, verbose)
#     298     start_time = timeit.default_timer()
#     299
# --> 300     epoch = 0
#     301     done_looping = False
#     302
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     786                         s.storage[0] = s.type.filter(
#     787                             arg, strict=s.strict,
# --> 788                             allow_downcast=s.allow_downcast)
#     789
#     790                     except Exception as e:
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/type.pyc in filter(self, data, strict, allow_downcast)
#     153                     if TensorType.values_eq(numpy.asarray(data),
#     154                                             converted_data,
# --> 155                                             force_same_dtype=False):
#     156                         data = converted_data
#     157                     else:
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/type.pyc in values_eq(a, b, force_same_dtype)
#     307             return False
#     308         a_eq_b = (a == b)
# --> 309         r = numpy.all(a_eq_b)
#     310         if r:
#     311             return True
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in all(a, axis, out, keepdims)
#    2028
#    2029     """
# -> 2030     arr = asanyarray(a)
#    2031
#    2032     try:
#
# KeyboardInterrupt:

# %%
import theano.tensor as T
from test_layer import test_network


#test_network(n_layers, activation=T.Tanh, learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
#            batch_size=20, n_hidden=500, verbose=False, Highway=False)

#val_matrix, test_matrix = test_network(n_layers = 10, n_epochs = 2, n_hidden=50, verbose=True,
 #                                     Highway = True)

val_matrix, test_matrix = test_network(n_layers = 10, n_epochs = 2, batch_size=20, n_hidden=50, verbose=True,
                                      Highway = True)
# Out:
# ... building the model
# ... training
# epoch 1, minibatch 2500/2500, validation error 9.140000 %
#      epoch 1, minibatch 2500/2500, test error of best model 9.670000 %
# epoch 2, minibatch 2500/2500, validation error 5.960000 %
#      epoch 2, minibatch 2500/2500, test error of best model 6.510000 %
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# The code for file test_layer.py ran for 0.51m
# Optimization complete. Best validation score of 5.960000 % obtained at iteration 5000, with test performance 6.510000 %

# %%
# %run test_layer.py
# Out:
# ... building the model
# ... training
# 0.0168281700462
# epoch 1, minibatch 2500/2500, validation error 9.540000 %
#      epoch 1, minibatch 2500/2500, test error of best model 9.770000 %
# 0.00238269451074
# epoch 2, minibatch 2500/2500, validation error 7.350000 %
#      epoch 2, minibatch 2500/2500, test error of best model 8.000000 %
# 0.00101626024116
# epoch 3, minibatch 2500/2500, validation error 5.360000 %
#      epoch 3, minibatch 2500/2500, test error of best model 5.990000 %

# %%
# %run test_layer.py
# Out:
# ... building the model
# ... training
# epoch 1, minibatch 2500/2500, validation error 13.260000 %
#      epoch 1, minibatch 2500/2500, test error of best model 13.850000 %
# epoch 2, minibatch 2500/2500, validation error 9.970000 %
#      epoch 2, minibatch 2500/2500, test error of best model 10.720000 %
# epoch 3, minibatch 2500/2500, validation error 7.110000 %
#      epoch 3, minibatch 2500/2500, test error of best model 7.360000 %
# epoch 4, minibatch 2500/2500, validation error 5.570000 %
#      epoch 4, minibatch 2500/2500, test error of best model 5.880000 %
# epoch 5, minibatch 2500/2500, validation error 5.100000 %
#      epoch 5, minibatch 2500/2500, test error of best model 5.560000 %
# epoch 6, minibatch 2500/2500, validation error 4.520000 %
#      epoch 6, minibatch 2500/2500, test error of best model 4.830000 %
# epoch 7, minibatch 2500/2500, validation error 4.080000 %
#      epoch 7, minibatch 2500/2500, test error of best model 4.310000 %
# epoch 8, minibatch 2500/2500, validation error 3.900000 %
#      epoch 8, minibatch 2500/2500, test error of best model 4.190000 %
# epoch 9, minibatch 2500/2500, validation error 4.140000 %
# epoch 10, minibatch 2500/2500, validation error 3.630000 %
#      epoch 10, minibatch 2500/2500, test error of best model 3.920000 %
# epoch 11, minibatch 2500/2500, validation error 3.540000 %
#      epoch 11, minibatch 2500/2500, test error of best model 3.950000 %
# epoch 12, minibatch 2500/2500, validation error 3.670000 %
# epoch 13, minibatch 2500/2500, validation error 3.480000 %
#      epoch 13, minibatch 2500/2500, test error of best model 3.750000 %
# epoch 14, minibatch 2500/2500, validation error 3.990000 %
# epoch 15, minibatch 2500/2500, validation error 3.300000 %
#      epoch 15, minibatch 2500/2500, test error of best model 3.480000 %
# epoch 16, minibatch 2500/2500, validation error 3.690000 %
# epoch 17, minibatch 2500/2500, validation error 3.490000 %
# epoch 18, minibatch 2500/2500, validation error 3.100000 %
#      epoch 18, minibatch 2500/2500, test error of best model 3.230000 %
# epoch 19, minibatch 2500/2500, validation error 2.990000 %
#      epoch 19, minibatch 2500/2500, test error of best model 3.470000 %
# epoch 20, minibatch 2500/2500, validation error 3.220000 %
# epoch 21, minibatch 2500/2500, validation error 3.830000 %
# epoch 22, minibatch 2500/2500, validation error 3.180000 %
# epoch 23, minibatch 2500/2500, validation error 2.930000 %
#      epoch 23, minibatch 2500/2500, test error of best model 3.220000 %
# epoch 24, minibatch 2500/2500, validation error 2.970000 %
# epoch 25, minibatch 2500/2500, validation error 7.750000 %
# epoch 26, minibatch 2500/2500, validation error 3.210000 %
# epoch 27, minibatch 2500/2500, validation error 2.980000 %
# epoch 28, minibatch 2500/2500, validation error 2.740000 %
#      epoch 28, minibatch 2500/2500, test error of best model 2.850000 %
# epoch 29, minibatch 2500/2500, validation error 2.970000 %
# epoch 30, minibatch 2500/2500, validation error 3.100000 %
# epoch 31, minibatch 2500/2500, validation error 2.600000 %
#      epoch 31, minibatch 2500/2500, test error of best model 3.040000 %
# epoch 32, minibatch 2500/2500, validation error 2.860000 %
# epoch 33, minibatch 2500/2500, validation error 3.140000 %
# epoch 34, minibatch 2500/2500, validation error 2.490000 %
#      epoch 34, minibatch 2500/2500, test error of best model 2.810000 %
# epoch 35, minibatch 2500/2500, validation error 2.930000 %
# epoch 36, minibatch 2500/2500, validation error 2.580000 %
# epoch 37, minibatch 2500/2500, validation error 2.540000 %
# epoch 38, minibatch 2500/2500, validation error 2.600000 %
# epoch 39, minibatch 2500/2500, validation error 4.780000 %
# epoch 40, minibatch 2500/2500, validation error 2.540000 %
# epoch 41, minibatch 2500/2500, validation error 2.830000 %
# epoch 42, minibatch 2500/2500, validation error 2.830000 %
# epoch 43, minibatch 2500/2500, validation error 2.550000 %
# epoch 44, minibatch 2500/2500, validation error 2.560000 %
# epoch 45, minibatch 2500/2500, validation error 2.590000 %
# epoch 46, minibatch 2500/2500, validation error 2.500000 %
# epoch 47, minibatch 2500/2500, validation error 2.460000 %
#      epoch 47, minibatch 2500/2500, test error of best model 2.670000 %
# epoch 48, minibatch 2500/2500, validation error 3.110000 %
# epoch 49, minibatch 2500/2500, validation error 2.470000 %
# epoch 50, minibatch 2500/2500, validation error 2.470000 %
# epoch 51, minibatch 2500/2500, validation error 2.590000 %
# epoch 52, minibatch 2500/2500, validation error 2.450000 %
#      epoch 52, minibatch 2500/2500, test error of best model 2.800000 %
# epoch 53, minibatch 2500/2500, validation error 2.800000 %
# epoch 54, minibatch 2500/2500, validation error 2.660000 %
# epoch 55, minibatch 2500/2500, validation error 2.440000 %
#      epoch 55, minibatch 2500/2500, test error of best model 2.750000 %
# epoch 56, minibatch 2500/2500, validation error 2.470000 %
# epoch 57, minibatch 2500/2500, validation error 2.490000 %
# epoch 58, minibatch 2500/2500, validation error 2.860000 %
# epoch 59, minibatch 2500/2500, validation error 2.220000 %
#      epoch 59, minibatch 2500/2500, test error of best model 2.550000 %
# epoch 60, minibatch 2500/2500, validation error 2.840000 %
# epoch 61, minibatch 2500/2500, validation error 2.520000 %
# epoch 62, minibatch 2500/2500, validation error 2.480000 %
# epoch 63, minibatch 2500/2500, validation error 2.280000 %
# epoch 64, minibatch 2500/2500, validation error 2.550000 %
# epoch 65, minibatch 2500/2500, validation error 2.270000 %
# epoch 66, minibatch 2500/2500, validation error 2.420000 %
# epoch 67, minibatch 2500/2500, validation error 2.170000 %
#      epoch 67, minibatch 2500/2500, test error of best model 2.440000 %
# epoch 68, minibatch 2500/2500, validation error 2.140000 %
#      epoch 68, minibatch 2500/2500, test error of best model 2.400000 %
# epoch 69, minibatch 2500/2500, validation error 2.080000 %
#      epoch 69, minibatch 2500/2500, test error of best model 2.370000 %
# epoch 70, minibatch 2500/2500, validation error 2.180000 %
# epoch 71, minibatch 2500/2500, validation error 2.140000 %
# epoch 72, minibatch 2500/2500, validation error 2.070000 %
#      epoch 72, minibatch 2500/2500, test error of best model 2.350000 %
# epoch 73, minibatch 2500/2500, validation error 2.110000 %
# epoch 74, minibatch 2500/2500, validation error 2.160000 %
# epoch 75, minibatch 2500/2500, validation error 2.120000 %
# epoch 76, minibatch 2500/2500, validation error 2.150000 %
# epoch 77, minibatch 2500/2500, validation error 3.100000 %
# epoch 78, minibatch 2500/2500, validation error 2.450000 %
# epoch 79, minibatch 2500/2500, validation error 2.960000 %
# epoch 80, minibatch 2500/2500, validation error 2.340000 %
# epoch 81, minibatch 2500/2500, validation error 4.060000 %
# epoch 82, minibatch 2500/2500, validation error 2.150000 %
# epoch 83, minibatch 2500/2500, validation error 2.390000 %
# epoch 84, minibatch 2500/2500, validation error 2.950000 %
# epoch 85, minibatch 2500/2500, validation error 2.630000 %
# epoch 86, minibatch 2500/2500, validation error 2.430000 %
# epoch 87, minibatch 2500/2500, validation error 2.310000 %
# epoch 88, minibatch 2500/2500, validation error 2.930000 %
# epoch 89, minibatch 2500/2500, validation error 2.260000 %
# epoch 90, minibatch 2500/2500, validation error 2.200000 %
# epoch 91, minibatch 2500/2500, validation error 2.860000 %
# epoch 92, minibatch 2500/2500, validation error 2.640000 %
# epoch 93, minibatch 2500/2500, validation error 2.190000 %
# epoch 94, minibatch 2500/2500, validation error 2.190000 %
# epoch 95, minibatch 2500/2500, validation error 2.100000 %
# epoch 96, minibatch 2500/2500, validation error 2.130000 %
# epoch 97, minibatch 2500/2500, validation error 2.120000 %
# epoch 98, minibatch 2500/2500, validation error 2.110000 %
# epoch 99, minibatch 2500/2500, validation error 2.120000 %
# epoch 100, minibatch 2500/2500, validation error 2.120000 %
# epoch 101, minibatch 2500/2500, validation error 2.090000 %
# epoch 102, minibatch 2500/2500, validation error 2.150000 %
# epoch 103, minibatch 2500/2500, validation error 2.190000 %
# epoch 104, minibatch 2500/2500, validation error 2.160000 %
# epoch 105, minibatch 2500/2500, validation error 2.160000 %
# epoch 106, minibatch 2500/2500, validation error 2.160000 %
# epoch 107, minibatch 2500/2500, validation error 2.190000 %
# epoch 108, minibatch 2500/2500, validation error 2.200000 %
# epoch 109, minibatch 2500/2500, validation error 2.180000 %
# epoch 110, minibatch 2500/2500, validation error 2.180000 %
# epoch 111, minibatch 2500/2500, validation error 2.210000 %
# epoch 112, minibatch 2500/2500, validation error 2.210000 %
# epoch 113, minibatch 2500/2500, validation error 2.230000 %
# epoch 114, minibatch 2500/2500, validation error 2.240000 %
# epoch 115, minibatch 2500/2500, validation error 2.240000 %
# epoch 116, minibatch 2500/2500, validation error 2.240000 %
# epoch 117, minibatch 2500/2500, validation error 2.240000 %
# epoch 118, minibatch 2500/2500, validation error 2.280000 %
# epoch 119, minibatch 2500/2500, validation error 2.260000 %
# epoch 120, minibatch 2500/2500, validation error 2.290000 %
# epoch 121, minibatch 2500/2500, validation error 2.270000 %
# epoch 122, minibatch 2500/2500, validation error 2.290000 %
# epoch 123, minibatch 2500/2500, validation error 2.260000 %
# epoch 124, minibatch 2500/2500, validation error 2.440000 %
# epoch 125, minibatch 2500/2500, validation error 3.080000 %
# epoch 126, minibatch 2500/2500, validation error 2.430000 %
# epoch 127, minibatch 2500/2500, validation error 2.980000 %
# epoch 128, minibatch 2500/2500, validation error 3.090000 %
# epoch 129, minibatch 2500/2500, validation error 2.550000 %
# epoch 130, minibatch 2500/2500, validation error 2.490000 %
# epoch 131, minibatch 2500/2500, validation error 2.350000 %
# epoch 132, minibatch 2500/2500, validation error 2.410000 %
# epoch 133, minibatch 2500/2500, validation error 4.270000 %
# epoch 134, minibatch 2500/2500, validation error 2.590000 %
# epoch 135, minibatch 2500/2500, validation error 3.610000 %
# epoch 136, minibatch 2500/2500, validation error 2.840000 %
# epoch 137, minibatch 2500/2500, validation error 2.480000 %
# epoch 138, minibatch 2500/2500, validation error 2.290000 %
# epoch 139, minibatch 2500/2500, validation error 2.680000 %
# epoch 140, minibatch 2500/2500, validation error 2.210000 %
# epoch 141, minibatch 2500/2500, validation error 2.260000 %
# epoch 142, minibatch 2500/2500, validation error 2.580000 %
# epoch 143, minibatch 2500/2500, validation error 2.580000 %
# epoch 144, minibatch 2500/2500, validation error 2.330000 %
# epoch 145, minibatch 2500/2500, validation error 2.310000 %
# epoch 146, minibatch 2500/2500, validation error 2.250000 %
# epoch 147, minibatch 2500/2500, validation error 2.520000 %
# epoch 148, minibatch 2500/2500, validation error 2.180000 %
# epoch 149, minibatch 2500/2500, validation error 2.070000 %
#      epoch 149, minibatch 2500/2500, test error of best model 2.440000 %
# epoch 150, minibatch 2500/2500, validation error 2.040000 %
#      epoch 150, minibatch 2500/2500, test error of best model 2.360000 %
# epoch 151, minibatch 2500/2500, validation error 2.010000 %
#      epoch 151, minibatch 2500/2500, test error of best model 2.260000 %
# epoch 152, minibatch 2500/2500, validation error 2.060000 %
# epoch 153, minibatch 2500/2500, validation error 2.080000 %
# epoch 154, minibatch 2500/2500, validation error 2.120000 %
# epoch 155, minibatch 2500/2500, validation error 2.120000 %
# epoch 156, minibatch 2500/2500, validation error 2.110000 %
# epoch 157, minibatch 2500/2500, validation error 2.110000 %
# epoch 158, minibatch 2500/2500, validation error 2.140000 %
# epoch 159, minibatch 2500/2500, validation error 2.160000 %
# epoch 160, minibatch 2500/2500, validation error 2.150000 %
# epoch 161, minibatch 2500/2500, validation error 2.170000 %
# epoch 162, minibatch 2500/2500, validation error 2.130000 %
# epoch 163, minibatch 2500/2500, validation error 2.150000 %
# epoch 164, minibatch 2500/2500, validation error 2.140000 %
# epoch 165, minibatch 2500/2500, validation error 2.140000 %
# epoch 166, minibatch 2500/2500, validation error 2.160000 %
# epoch 167, minibatch 2500/2500, validation error 2.130000 %
# epoch 168, minibatch 2500/2500, validation error 2.130000 %
# epoch 169, minibatch 2500/2500, validation error 2.110000 %
# epoch 170, minibatch 2500/2500, validation error 2.120000 %
# epoch 171, minibatch 2500/2500, validation error 2.110000 %
# epoch 172, minibatch 2500/2500, validation error 2.100000 %
# epoch 173, minibatch 2500/2500, validation error 2.100000 %
# epoch 174, minibatch 2500/2500, validation error 2.100000 %
# epoch 175, minibatch 2500/2500, validation error 2.110000 %
# epoch 176, minibatch 2500/2500, validation error 2.120000 %
# epoch 177, minibatch 2500/2500, validation error 2.130000 %
# epoch 178, minibatch 2500/2500, validation error 2.180000 %
# epoch 179, minibatch 2500/2500, validation error 2.170000 %
# epoch 180, minibatch 2500/2500, validation error 2.180000 %
# epoch 181, minibatch 2500/2500, validation error 2.170000 %
# epoch 182, minibatch 2500/2500, validation error 2.180000 %
# epoch 183, minibatch 2500/2500, validation error 2.150000 %
# epoch 184, minibatch 2500/2500, validation error 2.160000 %
# epoch 185, minibatch 2500/2500, validation error 2.170000 %
# epoch 186, minibatch 2500/2500, validation error 2.170000 %
# epoch 187, minibatch 2500/2500, validation error 2.190000 %
# epoch 188, minibatch 2500/2500, validation error 2.180000 %
# epoch 189, minibatch 2500/2500, validation error 2.180000 %
# epoch 190, minibatch 2500/2500, validation error 2.200000 %
# epoch 191, minibatch 2500/2500, validation error 2.220000 %
# epoch 192, minibatch 2500/2500, validation error 2.230000 %
# epoch 193, minibatch 2500/2500, validation error 2.250000 %
# epoch 194, minibatch 2500/2500, validation error 2.220000 %
# epoch 195, minibatch 2500/2500, validation error 2.230000 %
# epoch 196, minibatch 2500/2500, validation error 2.240000 %
# epoch 197, minibatch 2500/2500, validation error 2.260000 %
# epoch 198, minibatch 2500/2500, validation error 2.270000 %
# epoch 199, minibatch 2500/2500, validation error 2.280000 %
# epoch 200, minibatch 2500/2500, validation error 2.310000 %
# epoch 201, minibatch 2500/2500, validation error 2.310000 %
# epoch 202, minibatch 2500/2500, validation error 2.310000 %
# epoch 203, minibatch 2500/2500, validation error 2.320000 %
# epoch 204, minibatch 2500/2500, validation error 2.330000 %
# epoch 205, minibatch 2500/2500, validation error 2.330000 %
# epoch 206, minibatch 2500/2500, validation error 2.350000 %
# epoch 207, minibatch 2500/2500, validation error 2.340000 %
# epoch 208, minibatch 2500/2500, validation error 2.340000 %
# epoch 209, minibatch 2500/2500, validation error 2.330000 %
# epoch 210, minibatch 2500/2500, validation error 2.330000 %
# epoch 211, minibatch 2500/2500, validation error 2.350000 %
# epoch 212, minibatch 2500/2500, validation error 2.330000 %
# epoch 213, minibatch 2500/2500, validation error 2.330000 %
# epoch 214, minibatch 2500/2500, validation error 2.340000 %
# epoch 215, minibatch 2500/2500, validation error 2.340000 %
# epoch 216, minibatch 2500/2500, validation error 2.340000 %
# epoch 217, minibatch 2500/2500, validation error 2.360000 %
# epoch 218, minibatch 2500/2500, validation error 2.360000 %
# epoch 219, minibatch 2500/2500, validation error 2.360000 %
# epoch 220, minibatch 2500/2500, validation error 2.360000 %
# epoch 221, minibatch 2500/2500, validation error 2.370000 %
# epoch 222, minibatch 2500/2500, validation error 2.390000 %
# epoch 223, minibatch 2500/2500, validation error 2.390000 %
# epoch 224, minibatch 2500/2500, validation error 2.390000 %
# epoch 225, minibatch 2500/2500, validation error 2.390000 %
# epoch 226, minibatch 2500/2500, validation error 2.390000 %
# epoch 227, minibatch 2500/2500, validation error 2.390000 %
# epoch 228, minibatch 2500/2500, validation error 2.400000 %
# epoch 229, minibatch 2500/2500, validation error 2.410000 %
# epoch 230, minibatch 2500/2500, validation error 2.440000 %
# epoch 231, minibatch 2500/2500, validation error 2.460000 %
# epoch 232, minibatch 2500/2500, validation error 2.460000 %
# epoch 233, minibatch 2500/2500, validation error 2.450000 %
# epoch 234, minibatch 2500/2500, validation error 2.470000 %
# epoch 235, minibatch 2500/2500, validation error 2.470000 %
# epoch 236, minibatch 2500/2500, validation error 2.460000 %
# epoch 237, minibatch 2500/2500, validation error 2.460000 %
# epoch 238, minibatch 2500/2500, validation error 2.470000 %
# epoch 239, minibatch 2500/2500, validation error 2.460000 %
# epoch 240, minibatch 2500/2500, validation error 2.470000 %
# epoch 241, minibatch 2500/2500, validation error 2.460000 %
# epoch 242, minibatch 2500/2500, validation error 2.460000 %
# epoch 243, minibatch 2500/2500, validation error 2.480000 %
# epoch 244, minibatch 2500/2500, validation error 2.480000 %
# epoch 245, minibatch 2500/2500, validation error 2.470000 %
# epoch 246, minibatch 2500/2500, validation error 2.470000 %
# epoch 247, minibatch 2500/2500, validation error 2.450000 %
# epoch 248, minibatch 2500/2500, validation error 2.440000 %
# epoch 249, minibatch 2500/2500, validation error 2.450000 %
# epoch 250, minibatch 2500/2500, validation error 2.440000 %
# epoch 251, minibatch 2500/2500, validation error 2.440000 %
# epoch 252, minibatch 2500/2500, validation error 2.440000 %
# epoch 253, minibatch 2500/2500, validation error 2.440000 %
# epoch 254, minibatch 2500/2500, validation error 2.430000 %
# epoch 255, minibatch 2500/2500, validation error 2.410000 %
# epoch 256, minibatch 2500/2500, validation error 2.430000 %
# epoch 257, minibatch 2500/2500, validation error 2.430000 %
# epoch 258, minibatch 2500/2500, validation error 2.470000 %
# epoch 259, minibatch 2500/2500, validation error 2.390000 %
# epoch 260, minibatch 2500/2500, validation error 5.240000 %
# epoch 261, minibatch 2500/2500, validation error 4.320000 %
# epoch 262, minibatch 2500/2500, validation error 3.160000 %
# epoch 263, minibatch 2500/2500, validation error 2.860000 %
# epoch 264, minibatch 2500/2500, validation error 4.150000 %
# epoch 265, minibatch 2500/2500, validation error 3.020000 %
# epoch 266, minibatch 2500/2500, validation error 2.620000 %
# epoch 267, minibatch 2500/2500, validation error 2.940000 %
# epoch 268, minibatch 2500/2500, validation error 2.940000 %
# epoch 269, minibatch 2500/2500, validation error 2.670000 %
# epoch 270, minibatch 2500/2500, validation error 2.440000 %
# epoch 271, minibatch 2500/2500, validation error 3.830000 %
# epoch 272, minibatch 2500/2500, validation error 2.540000 %
# epoch 273, minibatch 2500/2500, validation error 3.150000 %
# epoch 274, minibatch 2500/2500, validation error 2.690000 %
# epoch 275, minibatch 2500/2500, validation error 2.770000 %
# epoch 276, minibatch 2500/2500, validation error 2.530000 %
# epoch 277, minibatch 2500/2500, validation error 2.280000 %
# epoch 278, minibatch 2500/2500, validation error 2.390000 %
# epoch 279, minibatch 2500/2500, validation error 2.520000 %
# epoch 280, minibatch 2500/2500, validation error 2.370000 %
# epoch 281, minibatch 2500/2500, validation error 2.500000 %
# epoch 282, minibatch 2500/2500, validation error 2.710000 %
# epoch 283, minibatch 2500/2500, validation error 2.890000 %
# epoch 284, minibatch 2500/2500, validation error 2.300000 %
# epoch 285, minibatch 2500/2500, validation error 2.460000 %
# epoch 286, minibatch 2500/2500, validation error 2.220000 %
# epoch 287, minibatch 2500/2500, validation error 2.450000 %
# epoch 288, minibatch 2500/2500, validation error 3.070000 %
# epoch 289, minibatch 2500/2500, validation error 2.550000 %
# epoch 290, minibatch 2500/2500, validation error 2.530000 %
# epoch 291, minibatch 2500/2500, validation error 2.360000 %
# epoch 292, minibatch 2500/2500, validation error 2.370000 %
# epoch 293, minibatch 2500/2500, validation error 2.270000 %
# epoch 294, minibatch 2500/2500, validation error 2.500000 %
# epoch 295, minibatch 2500/2500, validation error 2.490000 %
# epoch 296, minibatch 2500/2500, validation error 2.820000 %
# epoch 297, minibatch 2500/2500, validation error 2.190000 %
# epoch 298, minibatch 2500/2500, validation error 2.320000 %
# epoch 299, minibatch 2500/2500, validation error 2.230000 %
# epoch 300, minibatch 2500/2500, validation error 2.400000 %
# epoch 301, minibatch 2500/2500, validation error 2.470000 %
# epoch 302, minibatch 2500/2500, validation error 2.400000 %
# epoch 303, minibatch 2500/2500, validation error 2.480000 %
# epoch 304, minibatch 2500/2500, validation error 2.220000 %
# epoch 305, minibatch 2500/2500, validation error 2.140000 %
# epoch 306, minibatch 2500/2500, validation error 2.350000 %
# epoch 307, minibatch 2500/2500, validation error 2.160000 %
# epoch 308, minibatch 2500/2500, validation error 2.210000 %
# epoch 309, minibatch 2500/2500, validation error 2.170000 %
# epoch 310, minibatch 2500/2500, validation error 2.150000 %
# epoch 311, minibatch 2500/2500, validation error 2.150000 %
# epoch 312, minibatch 2500/2500, validation error 2.150000 %
# epoch 313, minibatch 2500/2500, validation error 2.160000 %
# epoch 314, minibatch 2500/2500, validation error 2.150000 %
# epoch 315, minibatch 2500/2500, validation error 2.160000 %
# epoch 316, minibatch 2500/2500, validation error 2.170000 %
# epoch 317, minibatch 2500/2500, validation error 2.170000 %
# epoch 318, minibatch 2500/2500, validation error 2.180000 %
# epoch 319, minibatch 2500/2500, validation error 2.190000 %
# epoch 320, minibatch 2500/2500, validation error 2.190000 %
# epoch 321, minibatch 2500/2500, validation error 2.210000 %
# epoch 322, minibatch 2500/2500, validation error 2.230000 %
# epoch 323, minibatch 2500/2500, validation error 2.230000 %
# epoch 324, minibatch 2500/2500, validation error 2.210000 %
# epoch 325, minibatch 2500/2500, validation error 2.220000 %
# epoch 326, minibatch 2500/2500, validation error 2.220000 %
# epoch 327, minibatch 2500/2500, validation error 2.220000 %
# epoch 328, minibatch 2500/2500, validation error 2.230000 %
# epoch 329, minibatch 2500/2500, validation error 2.240000 %
# epoch 330, minibatch 2500/2500, validation error 2.230000 %
# epoch 331, minibatch 2500/2500, validation error 2.230000 %
# epoch 332, minibatch 2500/2500, validation error 2.230000 %
# epoch 333, minibatch 2500/2500, validation error 2.220000 %
# epoch 334, minibatch 2500/2500, validation error 2.240000 %
# epoch 335, minibatch 2500/2500, validation error 2.240000 %
# epoch 336, minibatch 2500/2500, validation error 2.250000 %
# epoch 337, minibatch 2500/2500, validation error 2.250000 %
# epoch 338, minibatch 2500/2500, validation error 2.270000 %
# epoch 339, minibatch 2500/2500, validation error 2.280000 %
# epoch 340, minibatch 2500/2500, validation error 2.280000 %
# epoch 341, minibatch 2500/2500, validation error 2.300000 %
# epoch 342, minibatch 2500/2500, validation error 2.320000 %
# epoch 343, minibatch 2500/2500, validation error 2.320000 %
# epoch 344, minibatch 2500/2500, validation error 2.340000 %
# epoch 345, minibatch 2500/2500, validation error 2.330000 %
# epoch 346, minibatch 2500/2500, validation error 2.340000 %
# epoch 347, minibatch 2500/2500, validation error 2.350000 %
# epoch 348, minibatch 2500/2500, validation error 2.340000 %
# epoch 349, minibatch 2500/2500, validation error 2.360000 %
# epoch 350, minibatch 2500/2500, validation error 2.340000 %
# epoch 351, minibatch 2500/2500, validation error 2.340000 %
# epoch 352, minibatch 2500/2500, validation error 2.340000 %
# epoch 353, minibatch 2500/2500, validation error 2.340000 %
# epoch 354, minibatch 2500/2500, validation error 2.330000 %
# epoch 355, minibatch 2500/2500, validation error 2.340000 %
# epoch 356, minibatch 2500/2500, validation error 2.340000 %
# epoch 357, minibatch 2500/2500, validation error 2.340000 %
# epoch 358, minibatch 2500/2500, validation error 2.340000 %
# epoch 359, minibatch 2500/2500, validation error 2.340000 %
# epoch 360, minibatch 2500/2500, validation error 2.330000 %
# epoch 361, minibatch 2500/2500, validation error 2.350000 %
# epoch 362, minibatch 2500/2500, validation error 2.350000 %
# epoch 363, minibatch 2500/2500, validation error 2.360000 %
# epoch 364, minibatch 2500/2500, validation error 2.390000 %
# epoch 365, minibatch 2500/2500, validation error 2.390000 %
# epoch 366, minibatch 2500/2500, validation error 2.410000 %
# epoch 367, minibatch 2500/2500, validation error 2.410000 %
# epoch 368, minibatch 2500/2500, validation error 2.400000 %
# epoch 369, minibatch 2500/2500, validation error 2.400000 %
# epoch 370, minibatch 2500/2500, validation error 2.390000 %
# epoch 371, minibatch 2500/2500, validation error 2.390000 %
# epoch 372, minibatch 2500/2500, validation error 2.390000 %
# epoch 373, minibatch 2500/2500, validation error 2.380000 %
# epoch 374, minibatch 2500/2500, validation error 2.380000 %
# epoch 375, minibatch 2500/2500, validation error 2.390000 %
# epoch 376, minibatch 2500/2500, validation error 2.400000 %
# epoch 377, minibatch 2500/2500, validation error 2.410000 %
# epoch 378, minibatch 2500/2500, validation error 2.390000 %
# epoch 379, minibatch 2500/2500, validation error 2.400000 %
# epoch 380, minibatch 2500/2500, validation error 2.400000 %
# epoch 381, minibatch 2500/2500, validation error 2.390000 %
# epoch 382, minibatch 2500/2500, validation error 2.390000 %
# epoch 383, minibatch 2500/2500, validation error 2.390000 %
# epoch 384, minibatch 2500/2500, validation error 2.390000 %
# epoch 385, minibatch 2500/2500, validation error 2.400000 %
# epoch 386, minibatch 2500/2500, validation error 2.390000 %
# epoch 387, minibatch 2500/2500, validation error 2.380000 %
# epoch 388, minibatch 2500/2500, validation error 2.380000 %
# epoch 389, minibatch 2500/2500, validation error 2.380000 %
# epoch 390, minibatch 2500/2500, validation error 2.370000 %
# epoch 391, minibatch 2500/2500, validation error 2.370000 %
# epoch 392, minibatch 2500/2500, validation error 2.410000 %
# epoch 393, minibatch 2500/2500, validation error 2.420000 %
# epoch 394, minibatch 2500/2500, validation error 2.430000 %
# epoch 395, minibatch 2500/2500, validation error 2.430000 %
# epoch 396, minibatch 2500/2500, validation error 2.430000 %
# epoch 397, minibatch 2500/2500, validation error 2.430000 %
# epoch 398, minibatch 2500/2500, validation error 2.430000 %
# epoch 399, minibatch 2500/2500, validation error 2.440000 %
# epoch 400, minibatch 2500/2500, validation error 2.450000 %
# Optimization complete. Best validation score of 2.010000 % obtained at iteration 377500, with test performance 2.260000 %
# ... building the model
# ... training
# epoch 1, minibatch 2500/2500, validation error 11.980000 %
#      epoch 1, minibatch 2500/2500, test error of best model 12.900000 %
# epoch 2, minibatch 2500/2500, validation error 6.130000 %
#      epoch 2, minibatch 2500/2500, test error of best model 6.820000 %
# epoch 3, minibatch 2500/2500, validation error 5.800000 %
#      epoch 3, minibatch 2500/2500, test error of best model 5.690000 %
# epoch 4, minibatch 2500/2500, validation error 4.870000 %
#      epoch 4, minibatch 2500/2500, test error of best model 5.230000 %
# epoch 5, minibatch 2500/2500, validation error 4.200000 %
#      epoch 5, minibatch 2500/2500, test error of best model 4.670000 %
# epoch 6, minibatch 2500/2500, validation error 4.110000 %
#      epoch 6, minibatch 2500/2500, test error of best model 4.750000 %
# epoch 7, minibatch 2500/2500, validation error 3.650000 %
#      epoch 7, minibatch 2500/2500, test error of best model 3.820000 %
# epoch 8, minibatch 2500/2500, validation error 3.440000 %
#      epoch 8, minibatch 2500/2500, test error of best model 4.000000 %
# epoch 9, minibatch 2500/2500, validation error 4.060000 %
# epoch 10, minibatch 2500/2500, validation error 3.520000 %
# epoch 11, minibatch 2500/2500, validation error 3.560000 %
# epoch 12, minibatch 2500/2500, validation error 3.540000 %
# epoch 13, minibatch 2500/2500, validation error 3.350000 %
#      epoch 13, minibatch 2500/2500, test error of best model 3.460000 %
# epoch 14, minibatch 2500/2500, validation error 3.220000 %
#      epoch 14, minibatch 2500/2500, test error of best model 3.400000 %
# epoch 15, minibatch 2500/2500, validation error 3.330000 %
# epoch 16, minibatch 2500/2500, validation error 3.250000 %
# epoch 17, minibatch 2500/2500, validation error 3.300000 %
# epoch 18, minibatch 2500/2500, validation error 3.150000 %
#      epoch 18, minibatch 2500/2500, test error of best model 3.460000 %
# epoch 19, minibatch 2500/2500, validation error 3.540000 %
# epoch 20, minibatch 2500/2500, validation error 3.090000 %
#      epoch 20, minibatch 2500/2500, test error of best model 3.190000 %
# epoch 21, minibatch 2500/2500, validation error 3.170000 %
# epoch 22, minibatch 2500/2500, validation error 2.910000 %
#      epoch 22, minibatch 2500/2500, test error of best model 3.240000 %
# epoch 23, minibatch 2500/2500, validation error 2.900000 %
#      epoch 23, minibatch 2500/2500, test error of best model 3.090000 %
# epoch 24, minibatch 2500/2500, validation error 2.910000 %
# epoch 25, minibatch 2500/2500, validation error 2.920000 %
# epoch 26, minibatch 2500/2500, validation error 3.210000 %
# epoch 27, minibatch 2500/2500, validation error 2.970000 %
# epoch 28, minibatch 2500/2500, validation error 3.120000 %
# epoch 29, minibatch 2500/2500, validation error 2.880000 %
#      epoch 29, minibatch 2500/2500, test error of best model 3.320000 %
# epoch 30, minibatch 2500/2500, validation error 2.850000 %
#      epoch 30, minibatch 2500/2500, test error of best model 3.160000 %
# epoch 31, minibatch 2500/2500, validation error 3.170000 %
# epoch 32, minibatch 2500/2500, validation error 2.890000 %
# epoch 33, minibatch 2500/2500, validation error 3.060000 %
# epoch 34, minibatch 2500/2500, validation error 2.960000 %
# epoch 35, minibatch 2500/2500, validation error 2.760000 %
#      epoch 35, minibatch 2500/2500, test error of best model 2.870000 %
# epoch 36, minibatch 2500/2500, validation error 2.910000 %
# epoch 37, minibatch 2500/2500, validation error 2.820000 %
# epoch 38, minibatch 2500/2500, validation error 2.940000 %
# epoch 39, minibatch 2500/2500, validation error 3.030000 %
# epoch 40, minibatch 2500/2500, validation error 3.220000 %
# epoch 41, minibatch 2500/2500, validation error 3.050000 %
# epoch 42, minibatch 2500/2500, validation error 3.170000 %
# epoch 43, minibatch 2500/2500, validation error 3.290000 %
# epoch 44, minibatch 2500/2500, validation error 2.950000 %
# epoch 45, minibatch 2500/2500, validation error 3.490000 %
# epoch 46, minibatch 2500/2500, validation error 3.890000 %
# epoch 47, minibatch 2500/2500, validation error 2.800000 %
# epoch 48, minibatch 2500/2500, validation error 2.790000 %
# epoch 49, minibatch 2500/2500, validation error 2.680000 %
#      epoch 49, minibatch 2500/2500, test error of best model 3.040000 %
# epoch 50, minibatch 2500/2500, validation error 2.720000 %
# epoch 51, minibatch 2500/2500, validation error 2.940000 %
# epoch 52, minibatch 2500/2500, validation error 3.060000 %
# epoch 53, minibatch 2500/2500, validation error 3.020000 %
# epoch 54, minibatch 2500/2500, validation error 2.660000 %
#      epoch 54, minibatch 2500/2500, test error of best model 2.950000 %
# epoch 55, minibatch 2500/2500, validation error 2.620000 %
#      epoch 55, minibatch 2500/2500, test error of best model 2.830000 %
# epoch 56, minibatch 2500/2500, validation error 2.890000 %
# epoch 57, minibatch 2500/2500, validation error 2.920000 %
# epoch 58, minibatch 2500/2500, validation error 2.860000 %
# epoch 59, minibatch 2500/2500, validation error 2.840000 %
# epoch 60, minibatch 2500/2500, validation error 2.580000 %
#      epoch 60, minibatch 2500/2500, test error of best model 2.690000 %
# epoch 61, minibatch 2500/2500, validation error 2.990000 %
# epoch 62, minibatch 2500/2500, validation error 2.930000 %
# epoch 63, minibatch 2500/2500, validation error 3.230000 %
# epoch 64, minibatch 2500/2500, validation error 2.650000 %
# epoch 65, minibatch 2500/2500, validation error 2.660000 %
# epoch 66, minibatch 2500/2500, validation error 2.690000 %
# epoch 67, minibatch 2500/2500, validation error 2.690000 %
# epoch 68, minibatch 2500/2500, validation error 2.850000 %
# epoch 69, minibatch 2500/2500, validation error 2.670000 %
# epoch 70, minibatch 2500/2500, validation error 2.990000 %
# epoch 71, minibatch 2500/2500, validation error 2.740000 %
# epoch 72, minibatch 2500/2500, validation error 2.900000 %
# epoch 73, minibatch 2500/2500, validation error 2.720000 %
# epoch 74, minibatch 2500/2500, validation error 2.620000 %
# epoch 75, minibatch 2500/2500, validation error 2.640000 %
# epoch 76, minibatch 2500/2500, validation error 2.610000 %
# epoch 77, minibatch 2500/2500, validation error 2.510000 %
#      epoch 77, minibatch 2500/2500, test error of best model 2.570000 %
# epoch 78, minibatch 2500/2500, validation error 2.950000 %
# epoch 79, minibatch 2500/2500, validation error 2.740000 %
# epoch 80, minibatch 2500/2500, validation error 2.750000 %
# epoch 81, minibatch 2500/2500, validation error 2.660000 %
# epoch 82, minibatch 2500/2500, validation error 2.560000 %
# epoch 83, minibatch 2500/2500, validation error 2.640000 %
# epoch 84, minibatch 2500/2500, validation error 2.620000 %
# epoch 85, minibatch 2500/2500, validation error 2.520000 %
# epoch 86, minibatch 2500/2500, validation error 2.790000 %
# epoch 87, minibatch 2500/2500, validation error 2.510000 %
# epoch 88, minibatch 2500/2500, validation error 2.800000 %
# epoch 89, minibatch 2500/2500, validation error 2.720000 %
# epoch 90, minibatch 2500/2500, validation error 2.470000 %
#      epoch 90, minibatch 2500/2500, test error of best model 2.650000 %
# epoch 91, minibatch 2500/2500, validation error 2.690000 %
# epoch 92, minibatch 2500/2500, validation error 2.620000 %
# epoch 93, minibatch 2500/2500, validation error 2.630000 %
# epoch 94, minibatch 2500/2500, validation error 2.520000 %
# epoch 95, minibatch 2500/2500, validation error 2.870000 %
# epoch 96, minibatch 2500/2500, validation error 2.490000 %
# epoch 97, minibatch 2500/2500, validation error 2.500000 %
# epoch 98, minibatch 2500/2500, validation error 2.700000 %
# epoch 99, minibatch 2500/2500, validation error 2.810000 %
# epoch 100, minibatch 2500/2500, validation error 2.380000 %
#      epoch 100, minibatch 2500/2500, test error of best model 2.490000 %
# epoch 101, minibatch 2500/2500, validation error 2.450000 %
# epoch 102, minibatch 2500/2500, validation error 2.430000 %
# epoch 103, minibatch 2500/2500, validation error 2.370000 %
#      epoch 103, minibatch 2500/2500, test error of best model 2.340000 %
# epoch 104, minibatch 2500/2500, validation error 2.380000 %
# epoch 105, minibatch 2500/2500, validation error 2.380000 %
# epoch 106, minibatch 2500/2500, validation error 2.370000 %
# epoch 107, minibatch 2500/2500, validation error 2.370000 %
# epoch 108, minibatch 2500/2500, validation error 2.380000 %
# epoch 109, minibatch 2500/2500, validation error 2.390000 %
# epoch 110, minibatch 2500/2500, validation error 2.380000 %
# epoch 111, minibatch 2500/2500, validation error 2.380000 %
# epoch 112, minibatch 2500/2500, validation error 2.370000 %
# epoch 113, minibatch 2500/2500, validation error 2.360000 %
#      epoch 113, minibatch 2500/2500, test error of best model 2.310000 %
# epoch 114, minibatch 2500/2500, validation error 2.370000 %
# epoch 115, minibatch 2500/2500, validation error 2.400000 %
# epoch 116, minibatch 2500/2500, validation error 2.370000 %
# epoch 117, minibatch 2500/2500, validation error 2.370000 %
# epoch 118, minibatch 2500/2500, validation error 2.370000 %
# epoch 119, minibatch 2500/2500, validation error 2.380000 %
# epoch 120, minibatch 2500/2500, validation error 2.390000 %
# epoch 121, minibatch 2500/2500, validation error 2.400000 %
# epoch 122, minibatch 2500/2500, validation error 2.400000 %
# epoch 123, minibatch 2500/2500, validation error 2.400000 %
# epoch 124, minibatch 2500/2500, validation error 2.400000 %
# epoch 125, minibatch 2500/2500, validation error 2.390000 %
# epoch 126, minibatch 2500/2500, validation error 2.380000 %
# epoch 127, minibatch 2500/2500, validation error 2.390000 %
# epoch 128, minibatch 2500/2500, validation error 2.380000 %
# epoch 129, minibatch 2500/2500, validation error 2.370000 %
# epoch 130, minibatch 2500/2500, validation error 2.370000 %
# epoch 131, minibatch 2500/2500, validation error 2.370000 %
# epoch 132, minibatch 2500/2500, validation error 2.370000 %
# epoch 133, minibatch 2500/2500, validation error 2.360000 %
# epoch 134, minibatch 2500/2500, validation error 2.370000 %
# epoch 135, minibatch 2500/2500, validation error 2.380000 %
# epoch 136, minibatch 2500/2500, validation error 2.390000 %
# epoch 137, minibatch 2500/2500, validation error 2.380000 %
# epoch 138, minibatch 2500/2500, validation error 2.390000 %
# epoch 139, minibatch 2500/2500, validation error 2.400000 %
# epoch 140, minibatch 2500/2500, validation error 2.400000 %
# epoch 141, minibatch 2500/2500, validation error 2.390000 %
# epoch 142, minibatch 2500/2500, validation error 2.370000 %
# epoch 143, minibatch 2500/2500, validation error 2.370000 %
# epoch 144, minibatch 2500/2500, validation error 2.370000 %
# epoch 145, minibatch 2500/2500, validation error 2.390000 %
# epoch 146, minibatch 2500/2500, validation error 2.390000 %
# epoch 147, minibatch 2500/2500, validation error 2.390000 %
# epoch 148, minibatch 2500/2500, validation error 2.420000 %
# epoch 149, minibatch 2500/2500, validation error 2.430000 %
# epoch 150, minibatch 2500/2500, validation error 2.430000 %
# epoch 151, minibatch 2500/2500, validation error 2.430000 %
# epoch 152, minibatch 2500/2500, validation error 2.440000 %
# epoch 153, minibatch 2500/2500, validation error 2.450000 %
# epoch 154, minibatch 2500/2500, validation error 2.450000 %
# epoch 155, minibatch 2500/2500, validation error 2.450000 %
# epoch 156, minibatch 2500/2500, validation error 2.450000 %
# epoch 157, minibatch 2500/2500, validation error 2.460000 %
# epoch 158, minibatch 2500/2500, validation error 2.470000 %
# epoch 159, minibatch 2500/2500, validation error 2.470000 %
# epoch 160, minibatch 2500/2500, validation error 2.460000 %
# epoch 161, minibatch 2500/2500, validation error 2.450000 %
# epoch 162, minibatch 2500/2500, validation error 2.440000 %
# epoch 163, minibatch 2500/2500, validation error 2.440000 %
# epoch 164, minibatch 2500/2500, validation error 2.430000 %
# epoch 165, minibatch 2500/2500, validation error 2.440000 %
# epoch 166, minibatch 2500/2500, validation error 2.420000 %
# epoch 167, minibatch 2500/2500, validation error 2.420000 %
# epoch 168, minibatch 2500/2500, validation error 2.440000 %
# epoch 169, minibatch 2500/2500, validation error 2.440000 %
# epoch 170, minibatch 2500/2500, validation error 2.430000 %
# epoch 171, minibatch 2500/2500, validation error 2.420000 %
# epoch 172, minibatch 2500/2500, validation error 2.420000 %
# epoch 173, minibatch 2500/2500, validation error 2.430000 %
# epoch 174, minibatch 2500/2500, validation error 2.430000 %
# epoch 175, minibatch 2500/2500, validation error 2.430000 %
# epoch 176, minibatch 2500/2500, validation error 2.430000 %
# epoch 177, minibatch 2500/2500, validation error 2.420000 %
# epoch 178, minibatch 2500/2500, validation error 2.420000 %
# epoch 179, minibatch 2500/2500, validation error 2.430000 %
# epoch 180, minibatch 2500/2500, validation error 2.440000 %
# epoch 181, minibatch 2500/2500, validation error 2.440000 %
# epoch 182, minibatch 2500/2500, validation error 3.010000 %
# epoch 183, minibatch 2500/2500, validation error 2.530000 %
# epoch 184, minibatch 2500/2500, validation error 2.770000 %
# epoch 185, minibatch 2500/2500, validation error 2.940000 %
# epoch 186, minibatch 2500/2500, validation error 2.830000 %
# epoch 187, minibatch 2500/2500, validation error 3.400000 %
# epoch 188, minibatch 2500/2500, validation error 2.570000 %
# epoch 189, minibatch 2500/2500, validation error 3.080000 %
# epoch 190, minibatch 2500/2500, validation error 2.490000 %
# epoch 191, minibatch 2500/2500, validation error 2.680000 %
# epoch 192, minibatch 2500/2500, validation error 2.690000 %
# epoch 193, minibatch 2500/2500, validation error 2.520000 %
# epoch 194, minibatch 2500/2500, validation error 2.590000 %
# epoch 195, minibatch 2500/2500, validation error 2.680000 %
# epoch 196, minibatch 2500/2500, validation error 3.250000 %
# epoch 197, minibatch 2500/2500, validation error 2.620000 %
# epoch 198, minibatch 2500/2500, validation error 2.550000 %
# epoch 199, minibatch 2500/2500, validation error 3.420000 %
# epoch 200, minibatch 2500/2500, validation error 2.430000 %
# epoch 201, minibatch 2500/2500, validation error 2.620000 %
# epoch 202, minibatch 2500/2500, validation error 2.560000 %
# epoch 203, minibatch 2500/2500, validation error 2.470000 %
# epoch 204, minibatch 2500/2500, validation error 2.760000 %
# epoch 205, minibatch 2500/2500, validation error 2.580000 %
# epoch 206, minibatch 2500/2500, validation error 2.510000 %
# epoch 207, minibatch 2500/2500, validation error 2.260000 %
#      epoch 207, minibatch 2500/2500, test error of best model 2.360000 %
# epoch 208, minibatch 2500/2500, validation error 2.330000 %
# epoch 209, minibatch 2500/2500, validation error 2.450000 %
# epoch 210, minibatch 2500/2500, validation error 2.500000 %
# epoch 211, minibatch 2500/2500, validation error 2.540000 %
# epoch 212, minibatch 2500/2500, validation error 2.390000 %
# epoch 213, minibatch 2500/2500, validation error 2.530000 %
# epoch 214, minibatch 2500/2500, validation error 2.560000 %
# epoch 215, minibatch 2500/2500, validation error 2.620000 %
# epoch 216, minibatch 2500/2500, validation error 2.580000 %
# epoch 217, minibatch 2500/2500, validation error 2.540000 %
# epoch 218, minibatch 2500/2500, validation error 2.560000 %
# epoch 219, minibatch 2500/2500, validation error 2.350000 %
# epoch 220, minibatch 2500/2500, validation error 3.020000 %
# epoch 221, minibatch 2500/2500, validation error 2.730000 %
# epoch 222, minibatch 2500/2500, validation error 2.580000 %
# epoch 223, minibatch 2500/2500, validation error 2.610000 %
# epoch 224, minibatch 2500/2500, validation error 2.580000 %
# epoch 225, minibatch 2500/2500, validation error 2.530000 %
# epoch 226, minibatch 2500/2500, validation error 2.590000 %
# epoch 227, minibatch 2500/2500, validation error 2.350000 %
# epoch 228, minibatch 2500/2500, validation error 2.410000 %
# epoch 229, minibatch 2500/2500, validation error 2.390000 %
# epoch 230, minibatch 2500/2500, validation error 2.340000 %
# epoch 231, minibatch 2500/2500, validation error 2.440000 %
# epoch 232, minibatch 2500/2500, validation error 2.440000 %
# epoch 233, minibatch 2500/2500, validation error 2.280000 %
# epoch 234, minibatch 2500/2500, validation error 2.250000 %
#      epoch 234, minibatch 2500/2500, test error of best model 2.360000 %
# epoch 235, minibatch 2500/2500, validation error 2.260000 %
# epoch 236, minibatch 2500/2500, validation error 2.260000 %
# epoch 237, minibatch 2500/2500, validation error 2.240000 %
#      epoch 237, minibatch 2500/2500, test error of best model 2.350000 %
# epoch 238, minibatch 2500/2500, validation error 2.240000 %
# epoch 239, minibatch 2500/2500, validation error 2.240000 %
# epoch 240, minibatch 2500/2500, validation error 2.230000 %
#      epoch 240, minibatch 2500/2500, test error of best model 2.360000 %
# epoch 241, minibatch 2500/2500, validation error 2.230000 %
# epoch 242, minibatch 2500/2500, validation error 2.260000 %
# epoch 243, minibatch 2500/2500, validation error 2.270000 %
# epoch 244, minibatch 2500/2500, validation error 2.280000 %
# epoch 245, minibatch 2500/2500, validation error 2.270000 %
# epoch 246, minibatch 2500/2500, validation error 2.290000 %
# epoch 247, minibatch 2500/2500, validation error 2.280000 %
# epoch 248, minibatch 2500/2500, validation error 2.280000 %
# epoch 249, minibatch 2500/2500, validation error 2.300000 %
# epoch 250, minibatch 2500/2500, validation error 2.290000 %
# epoch 251, minibatch 2500/2500, validation error 2.290000 %
# epoch 252, minibatch 2500/2500, validation error 2.290000 %
# epoch 253, minibatch 2500/2500, validation error 2.290000 %
# epoch 254, minibatch 2500/2500, validation error 2.310000 %
# epoch 255, minibatch 2500/2500, validation error 2.270000 %
# epoch 256, minibatch 2500/2500, validation error 2.270000 %
# epoch 257, minibatch 2500/2500, validation error 2.250000 %
# epoch 258, minibatch 2500/2500, validation error 2.240000 %
# epoch 259, minibatch 2500/2500, validation error 2.240000 %
# epoch 260, minibatch 2500/2500, validation error 2.230000 %
# epoch 261, minibatch 2500/2500, validation error 2.240000 %
# epoch 262, minibatch 2500/2500, validation error 2.250000 %
# epoch 263, minibatch 2500/2500, validation error 2.240000 %
# epoch 264, minibatch 2500/2500, validation error 2.240000 %
# epoch 265, minibatch 2500/2500, validation error 2.250000 %
# epoch 266, minibatch 2500/2500, validation error 2.250000 %
# epoch 267, minibatch 2500/2500, validation error 2.260000 %
# epoch 268, minibatch 2500/2500, validation error 2.260000 %
# epoch 269, minibatch 2500/2500, validation error 2.270000 %
# epoch 270, minibatch 2500/2500, validation error 2.270000 %
# epoch 271, minibatch 2500/2500, validation error 2.280000 %
# epoch 272, minibatch 2500/2500, validation error 2.270000 %
# epoch 273, minibatch 2500/2500, validation error 2.270000 %
# epoch 274, minibatch 2500/2500, validation error 2.250000 %
# epoch 275, minibatch 2500/2500, validation error 2.250000 %
# epoch 276, minibatch 2500/2500, validation error 2.240000 %
# epoch 277, minibatch 2500/2500, validation error 2.240000 %
# epoch 278, minibatch 2500/2500, validation error 2.240000 %
# epoch 279, minibatch 2500/2500, validation error 2.230000 %
# epoch 280, minibatch 2500/2500, validation error 2.230000 %
# epoch 281, minibatch 2500/2500, validation error 2.210000 %
#      epoch 281, minibatch 2500/2500, test error of best model 2.230000 %
# epoch 282, minibatch 2500/2500, validation error 2.210000 %
# epoch 283, minibatch 2500/2500, validation error 2.200000 %
#      epoch 283, minibatch 2500/2500, test error of best model 2.240000 %
# epoch 284, minibatch 2500/2500, validation error 2.180000 %
#      epoch 284, minibatch 2500/2500, test error of best model 2.270000 %
# epoch 285, minibatch 2500/2500, validation error 2.160000 %
#      epoch 285, minibatch 2500/2500, test error of best model 2.280000 %
# epoch 286, minibatch 2500/2500, validation error 2.180000 %
# epoch 287, minibatch 2500/2500, validation error 2.170000 %
# epoch 288, minibatch 2500/2500, validation error 2.200000 %
# epoch 289, minibatch 2500/2500, validation error 2.190000 %
# epoch 290, minibatch 2500/2500, validation error 2.180000 %
# epoch 291, minibatch 2500/2500, validation error 2.170000 %
# epoch 292, minibatch 2500/2500, validation error 2.170000 %
# epoch 293, minibatch 2500/2500, validation error 2.160000 %
# epoch 294, minibatch 2500/2500, validation error 2.180000 %
# epoch 295, minibatch 2500/2500, validation error 2.190000 %
# epoch 296, minibatch 2500/2500, validation error 2.200000 %
# epoch 297, minibatch 2500/2500, validation error 2.200000 %
# epoch 298, minibatch 2500/2500, validation error 2.210000 %
# epoch 299, minibatch 2500/2500, validation error 2.200000 %
# epoch 300, minibatch 2500/2500, validation error 2.180000 %
# epoch 301, minibatch 2500/2500, validation error 2.190000 %
# epoch 302, minibatch 2500/2500, validation error 2.190000 %
# epoch 303, minibatch 2500/2500, validation error 2.180000 %
# epoch 304, minibatch 2500/2500, validation error 2.180000 %
# epoch 305, minibatch 2500/2500, validation error 2.190000 %
# epoch 306, minibatch 2500/2500, validation error 2.200000 %
# epoch 307, minibatch 2500/2500, validation error 2.210000 %
# epoch 308, minibatch 2500/2500, validation error 2.200000 %
# epoch 309, minibatch 2500/2500, validation error 2.200000 %
# epoch 310, minibatch 2500/2500, validation error 2.200000 %
# epoch 311, minibatch 2500/2500, validation error 2.200000 %
# epoch 312, minibatch 2500/2500, validation error 2.210000 %
# epoch 313, minibatch 2500/2500, validation error 2.220000 %
# epoch 314, minibatch 2500/2500, validation error 2.210000 %
# epoch 315, minibatch 2500/2500, validation error 2.240000 %
# epoch 316, minibatch 2500/2500, validation error 2.210000 %
# epoch 317, minibatch 2500/2500, validation error 2.220000 %
# epoch 318, minibatch 2500/2500, validation error 2.220000 %
# epoch 319, minibatch 2500/2500, validation error 2.230000 %
# epoch 320, minibatch 2500/2500, validation error 2.230000 %
# epoch 321, minibatch 2500/2500, validation error 2.220000 %
# epoch 322, minibatch 2500/2500, validation error 2.220000 %
# epoch 323, minibatch 2500/2500, validation error 2.210000 %
# epoch 324, minibatch 2500/2500, validation error 13.800000 %
# epoch 325, minibatch 2500/2500, validation error 2.800000 %
# epoch 326, minibatch 2500/2500, validation error 2.450000 %
# epoch 327, minibatch 2500/2500, validation error 2.630000 %
# epoch 328, minibatch 2500/2500, validation error 2.670000 %
# epoch 329, minibatch 2500/2500, validation error 2.600000 %
# epoch 330, minibatch 2500/2500, validation error 2.590000 %
# epoch 331, minibatch 2500/2500, validation error 2.380000 %
# epoch 332, minibatch 2500/2500, validation error 2.690000 %
# epoch 333, minibatch 2500/2500, validation error 2.450000 %
# epoch 334, minibatch 2500/2500, validation error 2.430000 %
# epoch 335, minibatch 2500/2500, validation error 2.570000 %
# epoch 336, minibatch 2500/2500, validation error 2.770000 %
# epoch 337, minibatch 2500/2500, validation error 2.320000 %
# epoch 338, minibatch 2500/2500, validation error 2.470000 %
# epoch 339, minibatch 2500/2500, validation error 2.530000 %
# epoch 340, minibatch 2500/2500, validation error 2.770000 %
# epoch 341, minibatch 2500/2500, validation error 2.740000 %
# epoch 342, minibatch 2500/2500, validation error 3.080000 %
# epoch 343, minibatch 2500/2500, validation error 2.400000 %
# epoch 344, minibatch 2500/2500, validation error 2.300000 %
# epoch 345, minibatch 2500/2500, validation error 2.380000 %
# epoch 346, minibatch 2500/2500, validation error 2.750000 %
# epoch 347, minibatch 2500/2500, validation error 2.590000 %
# epoch 348, minibatch 2500/2500, validation error 2.550000 %
# epoch 349, minibatch 2500/2500, validation error 2.560000 %
# epoch 350, minibatch 2500/2500, validation error 2.360000 %
# epoch 351, minibatch 2500/2500, validation error 2.410000 %
# epoch 352, minibatch 2500/2500, validation error 2.480000 %
# epoch 353, minibatch 2500/2500, validation error 2.490000 %
# epoch 354, minibatch 2500/2500, validation error 2.440000 %
# epoch 355, minibatch 2500/2500, validation error 2.580000 %
# epoch 356, minibatch 2500/2500, validation error 2.360000 %
# epoch 357, minibatch 2500/2500, validation error 2.550000 %
# epoch 358, minibatch 2500/2500, validation error 2.610000 %
# epoch 359, minibatch 2500/2500, validation error 2.230000 %
# epoch 360, minibatch 2500/2500, validation error 2.180000 %
# epoch 361, minibatch 2500/2500, validation error 2.350000 %
# epoch 362, minibatch 2500/2500, validation error 2.850000 %
# epoch 363, minibatch 2500/2500, validation error 2.660000 %
# epoch 364, minibatch 2500/2500, validation error 2.400000 %
# epoch 365, minibatch 2500/2500, validation error 2.420000 %
# epoch 366, minibatch 2500/2500, validation error 2.590000 %
# epoch 367, minibatch 2500/2500, validation error 2.400000 %
# epoch 368, minibatch 2500/2500, validation error 2.400000 %
# epoch 369, minibatch 2500/2500, validation error 2.390000 %
# epoch 370, minibatch 2500/2500, validation error 2.500000 %
# epoch 371, minibatch 2500/2500, validation error 2.340000 %
# epoch 372, minibatch 2500/2500, validation error 2.170000 %
# epoch 373, minibatch 2500/2500, validation error 2.310000 %
# epoch 374, minibatch 2500/2500, validation error 2.270000 %
# epoch 375, minibatch 2500/2500, validation error 2.760000 %
# epoch 376, minibatch 2500/2500, validation error 2.300000 %
# epoch 377, minibatch 2500/2500, validation error 2.330000 %
# epoch 378, minibatch 2500/2500, validation error 2.510000 %
# epoch 379, minibatch 2500/2500, validation error 2.480000 %
# epoch 380, minibatch 2500/2500, validation error 2.230000 %
# epoch 381, minibatch 2500/2500, validation error 2.250000 %
# epoch 382, minibatch 2500/2500, validation error 2.750000 %
# epoch 383, minibatch 2500/2500, validation error 2.810000 %
# epoch 384, minibatch 2500/2500, validation error 2.570000 %
# epoch 385, minibatch 2500/2500, validation error 2.320000 %
# epoch 386, minibatch 2500/2500, validation error 2.700000 %
# epoch 387, minibatch 2500/2500, validation error 2.480000 %
# epoch 388, minibatch 2500/2500, validation error 2.590000 %
# epoch 389, minibatch 2500/2500, validation error 2.290000 %
# epoch 390, minibatch 2500/2500, validation error 2.530000 %
# epoch 391, minibatch 2500/2500, validation error 2.360000 %
# epoch 392, minibatch 2500/2500, validation error 2.360000 %
# epoch 393, minibatch 2500/2500, validation error 2.430000 %
# epoch 394, minibatch 2500/2500, validation error 2.490000 %
# epoch 395, minibatch 2500/2500, validation error 2.520000 %
# epoch 396, minibatch 2500/2500, validation error 2.610000 %
# epoch 397, minibatch 2500/2500, validation error 2.850000 %
# epoch 398, minibatch 2500/2500, validation error 2.870000 %
# epoch 399, minibatch 2500/2500, validation error 2.370000 %
# epoch 400, minibatch 2500/2500, validation error 2.430000 %
# The code for file test_layer.py ran for 97.03m
# The code for file test_layer.py ran for 223.68m
# Optimization complete. Best validation score of 2.160000 % obtained at iteration 712500, with test performance 2.280000 %

# %%
from test_layer import test_network


#test_network(n_layers, activation=T.Tanh, learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=1000,
#            batch_size=20, n_hidden=500, verbose=False)

test_network(n_layers = 10, n_epochs = 400, verbose=True)
# Out:
# ... building the model
# ... training
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-bf8b81e1daf5> in <module>()
#       5 #            batch_size=20, n_hidden=500, verbose=False)
#       6
# ----> 7 test_network(n_layers = 10, n_epochs = 400, verbose=True)
#
# /home/ubuntu/project/e4040_project_abcd/src/test_layer.pyc in test_network(n_layers, activation, learning_rate, L1_reg, L2_reg, n_epochs, batch_size, n_hidden, verbose)
#     279         for minibatch_index in range(n_train_batches):
#     280
# --> 281             minibatch_avg_cost = train_model(minibatch_index)
#     282             # iteration number
#     283             iter = (epoch - 1) * n_train_batches + minibatch_index
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     877                     node=self.fn.nodes[self.fn.position_of_error],
#     878                     thunk=thunk,
# --> 879                     storage_map=getattr(self.fn, 'storage_map', None))
#     880             else:
#     881                 # old-style linkers raise their own exceptions
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/gof/link.pyc in raise_with_op(node, thunk, exc_info, storage_map)
#     323         # extra long error message in that case.
#     324         pass
# --> 325     reraise(exc_type, exc_value, exc_trace)
#     326
#     327
#
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     864         try:
#     865             outputs =\
# --> 866                 self.fn() if output_subset is None else\
#     867                 self.fn(output_subset=output_subset)
#     868         except Exception:
#
# ValueError: dimension mismatch in args to gemm (20,500)x(20,500)->(20,500)
# Apply node that caused the error: GpuDot22(GpuElemwise{Add}[(0, 0)].0, GpuElemwise{Add}[(0, 0)].0)
# Toposort index: 72
# Inputs types: [CudaNdarrayType(float32, matrix), CudaNdarrayType(float32, matrix)]
# Inputs shapes: [(20, 500), (20, 500)]
# Inputs strides: [(500, 1), (500, 1)]
# Inputs values: ['not shown', 'not shown']
# Outputs clients: [[GpuGemm{inplace}(GpuDot22.0, TensorConstant{1.0}, GpuElemwise{Composite{tanh((i0 + i1))}}[(0, 0)].0, GpuElemwise{sub,no_inplace}.0, TensorConstant{1.0})]]
#
# HINT: Re-running with most Theano optimization disabled could give you a back-trace of when this node was created. This can be done with by setting the Theano flag 'optimizer=fast_compile'. If that does not work, Theano optimizations can be disabled with 'optimizer=None'.
# HINT: Use the Theano flag 'exception_verbosity=high' for a debugprint and storage map footprint of this apply node.
